# %% [markdown]
# ## Qualitative Feedback Process
#
# Requires python >= 3.9.7
#
# ```bash
# pip install pandas langid txtai sacremoses sentencepiece langchain nltk
# ```
#
# before getting started, install ollama
#
# ```bash
# curl https://ollama.ai/install.sh | sh
# ollama pull bodeby/qsf
# ollama run bodeby/qsf
# ```
#
# For increased reproducebility utilize modelfile in project
# to build model with fixed seed and 0 temperature.
#
# ```bash
# curl https://ollama.ai/install.sh | sh
# ollama create bodeby/qsf -f ./modelfile
# ollama run bodeby/qsf #
# ```

# %%
# installation of required packages
# %pip install pandas langid txtai sacremoses sentencepiece langchain nltk matplotlib
# Out:
# Requirement already satisfied: pandas in ./.venv/lib/python3.12/site-packages (2.2.1)
# Requirement already satisfied: langid in ./.venv/lib/python3.12/site-packages (1.1.6)
# Requirement already satisfied: txtai in ./.venv/lib/python3.12/site-packages (7.0.0)
# Requirement already satisfied: sacremoses in ./.venv/lib/python3.12/site-packages (0.1.1)
# Requirement already satisfied: sentencepiece in ./.venv/lib/python3.12/site-packages (0.2.0)
# Requirement already satisfied: langchain in ./.venv/lib/python3.12/site-packages (0.1.13)
# Requirement already satisfied: nltk in ./.venv/lib/python3.12/site-packages (3.8.1)
# Requirement already satisfied: matplotlib in ./.venv/lib/python3.12/site-packages (3.8.3)
# Requirement already satisfied: numpy<2,>=1.26.0 in ./.venv/lib/python3.12/site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./.venv/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in ./.venv/lib/python3.12/site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in ./.venv/lib/python3.12/site-packages (from pandas) (2024.1)
# Requirement already satisfied: faiss-cpu>=1.7.1.post2 in ./.venv/lib/python3.12/site-packages (from txtai) (1.8.0)
# Requirement already satisfied: torch>=1.12.1 in ./.venv/lib/python3.12/site-packages (from txtai) (2.2.1)
# Requirement already satisfied: transformers>=4.27.0 in ./.venv/lib/python3.12/site-packages (from txtai) (4.39.0)
# Requirement already satisfied: huggingface-hub>=0.9.0 in ./.venv/lib/python3.12/site-packages (from txtai) (0.21.4)
# Requirement already satisfied: pyyaml>=5.3 in ./.venv/lib/python3.12/site-packages (from txtai) (6.0.1)
# Requirement already satisfied: regex>=2022.8.17 in ./.venv/lib/python3.12/site-packages (from txtai) (2023.12.25)
# Requirement already satisfied: click in ./.venv/lib/python3.12/site-packages (from sacremoses) (8.1.7)
# Requirement already satisfied: joblib in ./.venv/lib/python3.12/site-packages (from sacremoses) (1.3.2)
# Requirement already satisfied: tqdm in ./.venv/lib/python3.12/site-packages (from sacremoses) (4.66.2)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in ./.venv/lib/python3.12/site-packages (from langchain) (2.0.28)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in ./.venv/lib/python3.12/site-packages (from langchain) (3.9.3)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in ./.venv/lib/python3.12/site-packages (from langchain) (0.6.4)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in ./.venv/lib/python3.12/site-packages (from langchain) (1.33)
# Requirement already satisfied: langchain-community<0.1,>=0.0.29 in ./.venv/lib/python3.12/site-packages (from langchain) (0.0.29)
# Requirement already satisfied: langchain-core<0.2.0,>=0.1.33 in ./.venv/lib/python3.12/site-packages (from langchain) (0.1.33)
# Requirement already satisfied: langchain-text-splitters<0.1,>=0.0.1 in ./.venv/lib/python3.12/site-packages (from langchain) (0.0.1)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.17 in ./.venv/lib/python3.12/site-packages (from langchain) (0.1.31)
# Requirement already satisfied: pydantic<3,>=1 in ./.venv/lib/python3.12/site-packages (from langchain) (2.6.4)
# Requirement already satisfied: requests<3,>=2 in ./.venv/lib/python3.12/site-packages (from langchain) (2.31.0)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in ./.venv/lib/python3.12/site-packages (from langchain) (8.2.3)
# Requirement already satisfied: contourpy>=1.0.1 in ./.venv/lib/python3.12/site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in ./.venv/lib/python3.12/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in ./.venv/lib/python3.12/site-packages (from matplotlib) (4.50.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./.venv/lib/python3.12/site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in ./.venv/lib/python3.12/site-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=8 in ./.venv/lib/python3.12/site-packages (from matplotlib) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in ./.venv/lib/python3.12/site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: aiosignal>=1.1.2 in ./.venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in ./.venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in ./.venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in ./.venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in ./.venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.9.4)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in ./.venv/lib/python3.12/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain) (3.21.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in ./.venv/lib/python3.12/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain) (0.9.0)
# Requirement already satisfied: filelock in ./.venv/lib/python3.12/site-packages (from huggingface-hub>=0.9.0->txtai) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in ./.venv/lib/python3.12/site-packages (from huggingface-hub>=0.9.0->txtai) (2024.3.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in ./.venv/lib/python3.12/site-packages (from huggingface-hub>=0.9.0->txtai) (4.10.0)
# Requirement already satisfied: jsonpointer>=1.9 in ./.venv/lib/python3.12/site-packages (from jsonpatch<2.0,>=1.33->langchain) (2.4)
# Requirement already satisfied: anyio<5,>=3 in ./.venv/lib/python3.12/site-packages (from langchain-core<0.2.0,>=0.1.33->langchain) (4.3.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in ./.venv/lib/python3.12/site-packages (from langsmith<0.2.0,>=0.1.17->langchain) (3.9.15)
# Requirement already satisfied: annotated-types>=0.4.0 in ./.venv/lib/python3.12/site-packages (from pydantic<3,>=1->langchain) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.3 in ./.venv/lib/python3.12/site-packages (from pydantic<3,>=1->langchain) (2.16.3)
# Requirement already satisfied: six>=1.5 in ./.venv/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./.venv/lib/python3.12/site-packages (from requests<3,>=2->langchain) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in ./.venv/lib/python3.12/site-packages (from requests<3,>=2->langchain) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./.venv/lib/python3.12/site-packages (from requests<3,>=2->langchain) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in ./.venv/lib/python3.12/site-packages (from requests<3,>=2->langchain) (2024.2.2)
# Requirement already satisfied: sympy in ./.venv/lib/python3.12/site-packages (from torch>=1.12.1->txtai) (1.12)
# Requirement already satisfied: networkx in ./.venv/lib/python3.12/site-packages (from torch>=1.12.1->txtai) (3.2.1)
# Requirement already satisfied: jinja2 in ./.venv/lib/python3.12/site-packages (from torch>=1.12.1->txtai) (3.1.3)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in ./.venv/lib/python3.12/site-packages (from transformers>=4.27.0->txtai) (0.15.2)
# Requirement already satisfied: safetensors>=0.4.1 in ./.venv/lib/python3.12/site-packages (from transformers>=4.27.0->txtai) (0.4.2)
# Requirement already satisfied: sniffio>=1.1 in ./.venv/lib/python3.12/site-packages (from anyio<5,>=3->langchain-core<0.2.0,>=0.1.33->langchain) (1.3.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in ./.venv/lib/python3.12/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain) (1.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in ./.venv/lib/python3.12/site-packages (from jinja2->torch>=1.12.1->txtai) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in ./.venv/lib/python3.12/site-packages (from sympy->torch>=1.12.1->txtai) (1.3.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Package imports
import pandas as pd
import langid
import nltk
import re, os

from langchain.llms import Ollama
from txtai.pipeline import Translation
from nltk.tokenize import word_tokenize

# Download the punkt tokenizer data
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /Users/vk64lk/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %% [markdown]
# ## Processing Configuration
#
# **Notes on Translation**
# - True:  translate text manually using ```translate_text()```.
# - False: Ollama (language model) will attempt auto translation perhaps.
#
#
# **Model Selection**
# - Llama2:7b served with Ollama
# - QSF:7b (llama2) served with Ollama
#
# **File Paths**
# - Input: the dataset to work with
# - Output: the complete actionable feedback
# - Logs: intermediary log-level events

# %%
translate_text_manually = False     # toggle translation
max_token_context_length = 2000     # size of context
# ollama_model = "llama2"           # language model (zero-shot)
ollama_model = "bodeby/qsf"         # language model (paramter tuned)

input_path = 'data/complete.csv'    # original dataset
output_path = "data/actionable.csv" # the generated actionable feedback
log_path = "data/log.csv"           # log-level data

# %% [markdown]
# **Output Config**
# - campus: limit feedback bycampus ["copenhagen", "aalborg", "all"]
# - semester: limit feedback by semester [1,3,5,7,9]
# - course: limit feedback by course [52]

# %%
campus = "all"                      # ["all", input...]
semester = "all"                    # ["all", input...]
course = "all"                      # ["all", input...]

# %% [markdown]
# ## Supporting Functions

# %%
def split_text_into_array(text, max_tokens=20):
    tokens = word_tokenize(text) # use nltk to tokenize input
    result_array = []

    current_chunk = []
    current_chunk_length = 0

    for token in tokens:
        if current_chunk_length + len(token) <= max_tokens:
            current_chunk.append(token)
            current_chunk_length += len(token)
        else:
            result_array.append(" ".join(current_chunk))
            current_chunk = [token]
            current_chunk_length = len(token)

    if current_chunk:
        result_array.append(" ".join(current_chunk))

    return result_array

# %% [markdown]
# ## Tranlation via txtai
#
# ```python
# lang, confidence = langid.classify(text) # language classification
# result = translate_text(text, lang) # utilizing txtai translation
# ```

# %%
# Original
def translate_text(text):
    lang, confidence = langid.classify(text)
    print(lang)
    if lang == "da":
        # Translate the text to a specific language
        translate = Translation()
        translation = []
        for x in text:
            translation.append(translate(x,"da", "en"))
        return translation
    if lang == "sv":
        # Translate the text to a specific language (e.g., Spanish)
        translate = Translation()
        translation = []
        for x in text:
            translation.append(translate(x,"sv", "en"))
        return translation
    if lang == "no":
        # Translate the text to a specific language (e.g., Spanish)
        translate = Translation()
        translation = []
        for x in text:
            translation.append(translate(x,"no", "en"))
        return translation
    return text

# %%
# Refactored
def translate_text(text, lang):
    # Translate the text to a specific language
    target = "en"
    translate = Translation()
    translation = []

    for word in text:
        translated = translate(word, lang, target)
        translation.append(translated)
    
    return translation

# %% [markdown]
# ## Logging result to CSV
#
# 1. check if previous log file exists
#     - read file, and load it into a pandas DF
#     - create new pandas DF with required columns
# 2. Create a new row with query and output information
# 3. Append new row to results DF
# 4. Save modified results DF to log-file.

# %%
# Original Code
def log_query(query,output):

    # Check if the CSV file exists
    if os.path.exists(log_path):
        # If the file exists, load it into a DataFrame
        log_df = pd.read_csv(log_path)
    else:
        # If the file doesn't exist, generate new data and save it to the CSV file
        log_df = pd.DataFrame(columns=['let_llama_translate', 'max_token_context_length','model','query','output'])
    new_row = {'let_llama_translate':translate_text_manually, 'max_token_context_length':max_token_context_length,'model':ollama_model,'query':query,'output':output}
    log_df = pd.concat([log_df, pd.DataFrame([new_row])], ignore_index=True)
    log_df.to_csv(log_path, index=False)

# %%
# Log the query and its output to a CSV file.
# @arg query: string -> the query string.
# @arg output: string -> The output generated from the query.
def log_query(query, output):

    # Check if the CSV file exists
    if os.path.exists(log_path):
        # Read file, and load it into a pandas DF
        log_df = pd.read_csv(log_path) 
    else:
        # Create new pandas DF with required columns
        log_df = pd.DataFrame(columns=['let_llama_translate', 'max_token_context_length', 'model', 'query', 'output'])

    # Create a new row with query and output information
    new_row = {
        'let_llama_translate': translate_text_manually,
        'max_token_context_length': max_token_context_length,
        'model': ollama_model,
        'query': query,
        'output': output
    }

    # Append the new row to the DataFrame
    log_df = pd.concat([log_df, pd.DataFrame([new_row])], ignore_index=True)

    # Save the DataFrame to the CSV file
    log_df.to_csv(log_path, index=False)

# %% [markdown]
# ## Data Processing and Cleaning
#
# **refactoring required** to increase presentability
#
# 1. Identify **Campus** from dataset
# 2. Identify **Semester** from dataset

# %%
# fixes the awfull formatting of the data, 
# --> Requirements for dataframe: assuming 63 columns, first 42 being feedback, and a total of 11 course columns
# @dataframe    : the dataframe to be processed
# @write_file   : decide if the results should be logged
def process_data(dataframe, write_file):
    # Create a new DataFrame with selected columns
    new_df = pd.DataFrame(columns=['Campus', 'Semester', 'Course','Feedback_good','Feedback_bad','Feedback_extra'])
    
    # Display the new DataFrame
    for index, row in dataframe.iterrows():
        #figure out the campus:
        campus = "Aalborg"
        semester = re.search(r'\d+', row['Semesterbetegnelse'])

        # Check if we can find a semester number in string
        if semester:
            semester = semester.group()
        if '-KBH' in str(row['Semesterbetegnelse']):
            campus = "Copenhagen"
        
        # harvesting feedback, assuming 63 columns.
        feedback_good = ""
        feedback_bad = ""
        feedback_extra = ""
        course = ""
        row_arr = row.to_numpy()

        # 
        for i in range(0,42,3):
            if translate_text_manually:
                feedback_good = translate_text(row_arr[i])
                feedback_bad = translate_text(row_arr[i+1])
                feedback_extra = translate_text(row_arr[i+2])
            else:
                feedback_good = row_arr[i]
                feedback_bad = row_arr[i+1]
                feedback_extra = row_arr[i+2]
            
            course = row_arr[int((46+(i/3)))]
            if i == 33:
                course = "Project"
            if i == 36:
                course = "Semester" 
            if i == 39:
                course = "Studiemiljø"

            if not ((pd.isna(feedback_good)) and (pd.isna(feedback_bad)) and (pd.isna(feedback_extra))):
                new_row = {'Campus':campus, 'Semester': semester, 'Course':course, 'Feedback_good':feedback_good,'Feedback_bad':feedback_bad,'Feedback_extra':feedback_extra}
                new_df = pd.concat([new_df, pd.DataFrame([new_row])], ignore_index=True)

    if write_file:
        new_df.to_csv("processed_data/proc_dataset.csv", index=False)
        
    return new_df

# %% [markdown]
# ## Helper functions
#
# NB: Only used for CLI portion of the program
#
# Directly used for user input matching, ex.:
#
# ```python
# if check_strings_in_array(user_input,['kbh','cph','copenhagen','købehavn'])[0]:
#     campus = "Copenhagen"
# ```

# %%
def check_strings_in_array(main_string, string_array):
    for substring in string_array:
        if substring.lower() in main_string.lower():
            return [True,substring]
    return [False,""]

# %% [markdown]
# ## Synthesising Formatted Dataset

# %%
# Load dataset from csv file (tab seperated, utf-16 encoded)
df = pd.read_csv(input_path, sep='\t', encoding='utf-16')

# %%
# Apply preproc. function to dataframe and overide
df = process_data(df, False)

# %%
# Sanity-check of preproc.
df.head()
# Out:
#     Campus Semester                                           Course  \
# 0  Aalborg        9                                           IT-ret
# 1  Aalborg        9  Specialiseringskursus i programmeringsteknologi
# 2  Aalborg        9                                          Project
# 3  Aalborg        9                                         Semester
# 4  Aalborg        9                                      Studiemiljø
#
#                                        Feedback_good  \
# 0  Alle undervisere var rigtig gode og engageret ...
# 1  Vi nåede alle at lave tre fremlæggelser i løbe...
# 2  Vejledere er engageret og gode til at give fee...
# 3  Godt samspil mellem specialiseringskurset og p...
# 4      Vi er glade for at have vores eget grupperum!
#
#                                         Feedback_bad  \
# 0  Fire timers forelæsning i træk er meget lang t...
# 1  Holdet var opdelt på en måde, så fremlæggelser...
# 2                                                NaN
# 3                                                NaN
# 4  Bedre køkkenfaciliteter i FRB 7 G (fx mikroovn...
#
#                                       Feedback_extra
# 0                                                NaN
# 1       Kurset fungerede fint selvom det var online.
# 2                                                NaN
# 3                                                NaN
# 4  De fleste grupperum på FRB 7 G står tomme/bliv...

# %% [markdown]
# ### Generating the Actionable Feedback
#
# - original values; are columns that are inherited from input dataset
# - analysis values; are columns that are placed for later analysis
# - outcome values; are the final actionable feedback generated with the LLM

# %%
# configuration of Ollama instance
ollama = Ollama(base_url="http://127.0.0.1:11434", model=ollama_model)

# %%
# Create query and process with Ollama
def gen_summarized(arr):
    shortened_feedback_text = ""
    arr_length = len(arr)
    max_size = str(int((max_token_context_length / arr_length)))

    for i in range(arr_length):
        # Query builder
        query = f"Summarize, to a maximum of {max_size} tokens this text that is based on course evaluations: {arr[i]}"

        # Process query
        output = ollama(query)  # Query Ollama Model
        log_query(query, output)  # Log output to CSV
        shortened_feedback_text += output  # Append output
    
    return {
        "query": query,
        "output": shortened_feedback_text
    }

# %%
# TEST: gen_summarized
test_feedback = "There are plenty of material. The invited lectures are interesting."

# Create Array af Tokens
test_array = split_text_into_array(test_feedback, max_tokens=max_token_context_length)
print(test_array)

# run ollama inference
result_summ = gen_summarized(test_array)

# destructure results
print(result_summ["query"])
print(result_summ["output"])
# Out:
# ['There are plenty of material . The invited lectures are interesting .']
# Summarize, to a maximum of 2000 tokens this text that is based on course evaluations: There are plenty of material . The invited lectures are interesting .
#
# Here's a summary of the text in up to 2000 tokens:
#
# There are many interesting materials in the course. Invited lectures are also enjoyable.

# %%
# Generate actionable feedback
def gen_actionable(summarized):
    query = f"You are now an actionable feedback bot. Summarize and give actionable feedback, based upon these summarized course evaluations, to the instructor of the course. Leave out names that could identify entities. Make sure that the feedback is factual, actionable, and appropriate to the instructor: {summarized}"
    output = ollama(query)  # Query Ollama Model
    log_query(query, output)  # Log query-output pair to CSV

    return {
        "query": query,
        "output": output
    }

# %%
# test of gen_actionable
test_summarized = "Provide better slides and planned activities"

# run ollama inference
result = gen_actionable(result_summ["output"])

# destructure results
print(result["query"])
print(result["output"])
# Out:
# You are now an actionable feedback bot. Summarize and give actionable feedback, based upon these summarized course evaluations, to the instructor of the course. Leave out names that could identify entities. Make sure that the feedback is factual, actionable, and appropriate to the instructor:
# Here's a summary of the text in up to 2000 tokens:
#
# There are many interesting materials in the course. Invited lectures are also enjoyable.
#
# Based on the summarized course evaluations provided, here is some actionable feedback for the instructor:
#
# "Overall, the course offers a diverse range of materials and lectures that appear engaging and informative for students. However, there may be opportunities to enhance the course content or delivery to further support student learning. Specifically:
#
# * Consider incorporating more interactive elements, such as in-class activities or online discussions, to keep students engaged and motivated.
# * Explore ways to provide additional context or background information on key concepts or topics, particularly for students who may be less familiar with the subject matter.
# * Encourage students to take a more active role in their learning by setting clear expectations and providing opportunities for self-assessment and feedback.
# * Consider offering additional resources or support, such as supplementary readings or tutoring, to help students who may be struggling with the material.
#
# By implementing these suggestions, you can help create a more dynamic and engaging learning environment that supports student success."

# %%
# Desired Columns in the output file
master = pd.DataFrame(
    columns=[
        "campus",           # original
        "semester",         # original
        "course",           # original
        "factuality",       # analysis
        "actionability",    # analysis
        "appropriateness",  # analysis
        "feedback_good",    # original
        "feedback_bad",     # orignal
        "feedback_extra",   # oroginal
        "summarize_query",  # product secondary
        "summarize_output", # product secondary
        "actionable_query", # product primary
        "actionable_output" # product primary
    ]
)

# %%
# initialize iteration counter (max courses: 52)
time_total = len(df["Course"].unique()) # iter-tracking
time_spent = 0                          # iter-tracking

# %%
# Notification
print("Starting generation of actionable feedback")

# Generate master file
for course in df["Course"].unique():

    # iteration tracking for console prints
    time_spent += 1
    print("step ", time_spent, "/", time_total)

    # generate copy of dataframe
    df_cpy = df.copy()
    df_cpy_course = df_cpy[df_cpy["Course"] == course]

    for campus in df_cpy_course["Campus"].unique():
        df_cpy_course_campus = df_cpy_course[df_cpy_course["Campus"] == campus]

        for semester in df_cpy_course_campus["Semester"].unique():
            # What?? 
            df_cpy_course_campus_semester = df_cpy_course_campus[
                df_cpy_course_campus["Semester"] == semester
            ]
            
            print(f"amount of responses: {len(df_cpy_course_campus_semester)}")

            if not df_cpy_course_campus.empty:
                feedback_good = ". ".join(df_cpy_course_campus_semester["Feedback_good"].dropna())
                feedback_bad = ". ".join(df_cpy_course_campus_semester["Feedback_bad"].dropna())
                feedback_extra = ". ".join(df_cpy_course_campus_semester["Feedback_extra"].dropna())

                # Concat feedback strings
                feedback = f'{feedback_good}. {feedback_bad}. {feedback_extra}'

                # Create Array af Tokens
                feedback_array = split_text_into_array(feedback, max_tokens=max_token_context_length)
                feedback_array_length = len(feedback_array)

                # Summarized feedback
                summarized_feedback = gen_summarized(feedback_array)
                print(f"Sum. result: {summarized_feedback["output"]}")

                # Generate Actionable feedback
                actionable_feedback = gen_actionable(summarized_feedback["output"])
                print(f"Act. result: {actionable_feedback["output"]}")


                # Define the new entry
                new_row = {
                    "campus": campus,
                    "semester": semester,
                    "course": course,
                    "factuality": "",
                    "actionability": "",
                    "appropriateness": "",
                    "feedback_good": feedback_good,
                    "feedback_bad": feedback_bad,
                    "feedback_extra": feedback_extra,
                    "summarize_query": summarized_feedback["query"],
                    "summarize_output": summarized_feedback["output"],
                    "actionable_query": actionable_feedback["query"],
                    "actionable_output": actionable_feedback["output"],
                }

                # Add the new row to master dataframe
                master = pd.concat([master, pd.DataFrame([new_row])], ignore_index=True)

master.to_csv(output_path, index=False)
# Out:
# Starting generation of actionable feedback
# step  1 / 52
# amount of responses: 6
# Sum. result: Here is a summary of the text in 1000 tokens or less:
#
# * Students found all lecturers to be good and engaged in their teaching.
# * Course content was relevant to the study material.
# * Lecturers were good at making the subject interesting, involving students actively, and making it relevant for future use.
# * Lectures were well-structured and engaging.
# * Students were enthusiastic and relatable to many technical things.
# * Four hours of lecturing per week was too long, especially in the afternoon.
# * Lectures could be split up into two per week for more practical exercises.
# * The course on criminal law was maybe a bit too broad.
# * There were some confusion about what constitutes a legally valid paragraph.
# * Both synopses and PMM assignments contained contradictory information.
# * There was no opportunity to follow the course material at home due to illness or uncertainty.
# * Synopses were not well-known on our education system, so the requirements were unclear.
# * The format of the synopsis was different from the actual synopsis, which made it difficult to ask questions to the lecturer.
# * There should have been more opportunities for individual and group discussions about a problematic situation instead of always being in plenum.
# * The amount of material should have been tailored to the course duration.
# * There were some things that were either self-study or that the lecturer had to skip due to time constraints. Here is a summary of the text in 1000 tokens or less:
#
# * Students find it difficult to balance coursework and their own specialization due to limited time.
# * Pauses can vary from too short to too long, so maybe have a fixed length pause.
# * Course instructors informed us that the workload is mostly in reading and lectures, which was not entirely clear from the start.
# * Good humor in assignments and slides, keep it up!
# * We were really happy with the course, so here are some suggestions for improvements.
# * Exam synopsis running concurrently with presentations in specialization courses creates time pressure.
# * The course was good but had relevant content, but we didn't investigate the topics ourselves.
# * Maybe not super clear that the exam was in December, but we were informed at the first lecture.
# Act. result: Dear Instructor,
#
# Thank you for your hard work and dedication to teaching this course. Based on the student evaluations, here are some actionable feedback points to improve the course experience:
#
# 1. Lecture duration: Students found that four hours of lecturing per week was too long, especially in the afternoon. Consider splitting the lectures into two per week to provide more time for practical exercises.
# 2. Course content: While students found the course content relevant and engaging, some suggested narrowing down the broad topic of criminal law to better focus the course material.
# 3. Synopses and PMM assignments: There were some confusion and contradictory information in the synopses and PMM assignments. Clarify the requirements and format of these assignments to avoid confusion.
# 4. Workload balance: Students found it challenging to balance coursework and their own specialization due to limited time. Ensure that the workload is balanced and manageable throughout the course.
# 5. Pauses: Vary the length of pauses between lectures to provide a more engaging learning experience.
# 6. Clarity on workload: While students were informed about the coursework at the first lecture, some found it not entirely clear from the start. Make sure to emphasize the workload and expectations early on in the course.
# 7. Humor in assignments and slides: Students appreciated the good humor in your assignments and slides. Keep up the good work!
# 8. Exam synopsis: Some students mentioned that the exam synopsis ran concurrently with presentations in specialization courses, creating time pressure. Consider adjusting the exam schedule to minimize conflicts.
# 9. Relevance of topics: While students found the course content relevant, some suggested investigating the topics themselves instead of just being informed about them. Encourage students to engage more deeply with the material through discussions and self-study.
# 10. Timely notifications: Students were informed at the first lecture that the exam was in December, but some found it not entirely clear from the start. Make sure to provide timely reminders and updates throughout the course to avoid any confusion.
#
# Thank you again for your dedication to teaching this course. I hope these feedback points help improve the student experience.
#
# Best regards,
# [Your Name]
# step  2 / 52
# amount of responses: 1
# Sum. result:
# In this text, the author reflects on their experience taking an online course. They mention that everyone in the class was able to complete three assignments, which they feel prepares them well for the final exam. The assignments were diverse and covered either process calculus or energy optimization in programming languages, which the author finds challenging as they are unrelated to their own topic. The author suggests that organizing the assignments in a more coherent manner would make the course more engaging and motivating, as it is demotivating to prepare for and give feedback on assignments that are far removed from one's own topic. Despite this, the author found the course to be effective overall, even though it was conducted online.
# Act. result:
# Based on the summarized course evaluations, here is some actionable feedback that can help the instructor improve their teaching methods:
#
# 1. Organize assignments more coherently: One of the students found the assignments to be unrelated to their topic, which made them less motivated. By organizing the assignments in a more coherent manner, you can help students see how each assignment is related to their overall learning goals and make the course more engaging.
# 2. Emphasize relevance: Since some students found the assignments unrelated to their topic, consider emphasizing how each assignment is relevant to their learning goals. This will help students see the purpose of each assignment and motivate them to complete them.
# 3. Provide clear instructions: Some students may have found the assignments challenging due to unclear instructions. Make sure you provide clear instructions for each assignment and make yourself available to answer questions or provide clarification as needed.
# 4. Encourage interaction: Since the course was conducted online, it's important to encourage interaction among students. Consider incorporating group discussions, peer review, or other interactive elements into the course to help build a sense of community among students.
# 5. Continuously evaluate and improve: Finally, continuously evaluate your teaching methods and look for ways to improve. Ask students for feedback regularly and make changes as needed to ensure that the course is effective and engaging for all students.
# step  3 / 52
# amount of responses: 12
# Sum. result: In this text, students evaluate their course on research and give feedback on various aspects. Here are the main points summarized in 1000 tokens or less:
#
# * Vejledere are engaged and good at giving feedback (58 tokens)
# * Interesting and motivating to work with research (49 tokens)
# * Good time management and flexibility in choosing topics to work on (53 tokens)
# * Positive experience working with vejleder Tim, both in terms of engagement and input (60 tokens)
# * Supervisors are very engaged and interested in the students' work (57 tokens)
# * Group communication is good (48 tokens)
# * Some problems arise quickly and are solved efficiently (49 tokens)
# * Lack of computer resources, but access to Claaudia (51 tokens)
# * Online meetings with vejleder can be difficult to hear what's being said (50 tokens)
# * Small group room should be shared with another group (47 tokens)
# * Introduction to the project could have been helpful (46 tokens)
# * It's often unclear what the goal is for this semester (48 tokens)
# * Huvud and bi-vejleder sometimes disagree, creating confusion in the group (51 tokens)
# * Vejleder attitude changes depending on whether bivejleder is present (52 tokens)
# * Quality of guidance depends on whether it's a suggestion from the vejleder or the group's own idea (49 tokens)
# * Vejledere sometimes seem uninterested in the project (48 tokens)
# * Confusion about specialization and how it fits into the project (50 tokens)
# * Allocating the entire yeargroup to a room designed for 10 people is confusing, especially during corona (62 tokens)
# * Make sure to check if your ML models converge; ) (49 tokens)
# The team is working with machine learning, but the data they have received is of poor quality and inadequate for evaluating model performance. This is demotivating for the project work. They have not found a solution to this problem, but have considered whether a veteran evaluator might be able to assess the issue before the project was proposed. It remains unclear why several groups were unable to work on the same topic.
# Act. result:
# Based on the summarized course evaluations, here is some actionable feedback for the instructor:
#
# 1. Improve communication and collaboration within the group: While the team is working well together, there are instances where communication breakdowns occur during online meetings. To address this, consider implementing a clear agenda or structure for these meetings to ensure everyone is on the same page. Additionally, encourage the group to communicate openly and regularly outside of these meetings.
# 2. Provide more guidance and support: Some students express confusion about the project's goals and specialization within the course. To address this, consider providing more detailed guidance and expectations at the beginning of the semester. Additionally, offer regular check-ins and support throughout the project to help the team stay on track.
# 3. Address issues with data quality: The poor quality of the data received is demotivating for the team and affecting their ability to evaluate model performance. To address this, consider providing more guidance on how to obtain high-quality data or offering additional resources to help the team improve their data collection methods.
# 4. Improve accessibility during online meetings: Some students have difficulty hearing during online meetings. To address this, consider using a different platform or implementing audio enhancements to improve sound quality. Additionally, encourage team members to ask questions and participate fully in meetings to avoid any potential communication issues.
# 5. Encourage active participation from all team members: While some students express positive feedback on the instructor's engagement and interest in their work, others mention instances where vejledere seem uninterested. To address this, consider encouraging all team members to actively participate in group discussions and decision-making processes. This can help ensure everyone feels invested in the project and more likely to contribute positively.
# 6. Clarify expectations for specialization: Some students express confusion about the project's focus and how it relates to their own specialization within the course. To address this, consider providing more detailed guidance on how each student's specialization fits into the overall project goals. Additionally, encourage team members to communicate openly and regularly about their areas of expertise and how they can contribute to the project.
# 7. Address issues with room allocation: Some students express confusion about why several groups were unable to work in the same room. To address this, consider providing more detailed guidance on room allocation and scheduling to ensure each team has access to the space they need. Additionally, encourage team members to communicate openly and regularly about any issues or concerns related to room allocation.
# 8. Provide additional resources for machine learning: While the team is working with machine learning, some students express difficulty with the data they have received. To address this, consider providing more guidance on how to work with poor-quality data or offering additional resources to help the team improve their data collection methods. Additionally, encourage team members to ask questions and seek help when needed to avoid any potential issues with model performance.
#
# By implementing these suggestions, the instructor can help address some of the challenges faced by the team and ensure a successful project outcome.
# amount of responses: 44
# Sum. result: * The course evaluations were generally positive, with students feeling that they had a good experience with their mentor and group work.
# * The opponent groups seemed to work well, but there was some confusion about the criteria to be met.
# * The grouped dancing session in P1 worked well, providing a good insight into the working life and giving the students a chance to practice their skills.
# * The teachers were seen as good mentors, providing guidance and feedback.
# * Some students felt that there were too many people in their group (7), but overall, the group work was seen as positive.
# * Both P0 and P1 had engaged mentors, but there were some differences between them.
# * The project market in P1 was a good idea, providing the students with practical experience.
# * The status seminar gave the students a good perspective on their projects, and provided valuable feedback.
# * The group's collaboration was seen as good, and the students felt that they had enough freedom to work on their projects.
# * Some students felt that the project frameworks covered too broad of a topic, making it difficult to choose a project.
# * The P1 project group formation was seen as a positive experience, providing the students with a chance to work on practical projects.
# * The mentors were seen as interested in the students' work and provided valuable feedback.
# * The students felt that the course provided them with a good opportunity to apply what they had learned in practice.
# * Some students noted that the level of the project proposals was high, but overall, the students were satisfied with their experience.Here is a summary of the text in 333 tokens or less:
#
# * The project evaluations were positive, with good group work and relevance to the course.
# * The project started well, with good introductions and vejledermøders.
# * The group was satisfied with the selection of embers and had good communication with the vejleder.
# * The project had a clear structure and purpose, and the groups were motivated to work on their projects.
# * The vejleder was supportive and helped the groups to stay on track.
# * The groups had good opportunities for development and feedback throughout the project.
# * The project was well-organized and had a good balance of individual and group work.
# * The vejledermøders were frequent and helpful, providing motivation and guidance to the groups.
# * The project had a clear purpose and was well-aligned with the course objectives.Here is a summary of the text in 333 tokens or less:
#
# * The course involved theory and practical work, with the most effective combination being a mix of both.
# * Thorlacius was praised for P1 in comparison to P0, as he could have written more for P0 than was done.
# * Expectations for P0 were unclear, but the seminar on project management was helpful in understanding the administrative side of things.
# * The opponent group was seen as good, as long as they were a competent group.
# * Vejlederne (the tutors) did a good job.
# * The course taught a lot about the problem-based learning approach and how it works.
# * There were some challenges with the group work, such as not having enough control over the situation.
# * It was recommended to give more information to students beforehand regarding the project start-up.
# * Having their own group room in P1 was seen as a positive difference.
# * The grouped dialnesse was chaotic, and it was suggested to provide more information to the students beforehand.
# * There were 4-5 members in each group, which was seen as optimal.
# * Two group members dropped out during the project phase, causing confusion in the group.
# * Physically, the project market in P1 would function better.
# * It is recommended to provide a better explanation of how a PBL project works, including the fact that when given the project outline, it is unclear how tightly the group should stick to the given problem stance.Here is a summary of the text in 333 tokens or less:
#
# * Importance of opponent group being well-prepared and actively participating with critical questions and thoughts. (47 tokens)
# * Difference in quality of feedback received, with some members feeling that the project catalog in P1 did not match what was needed for the project. (32 tokens)
# * Issues with groupedannelse, including lack of choice in selecting group members and feeling of being rushed during P0. (58 tokens)
# * Concerns about the usefulness of projector equipment for group work. (27 tokens)
# * Difficulty of working remotely and lack of engagement from absent group members. (49 tokens)
# * Need for better communication regarding sickness and absences, as well as introductions to projects instead of being thrown together in a group without proper guidance. (63 tokens)
# * Variations in vejleder attitudes towards how problem analysis should be conducted. (51 tokens)
# * Lack of knowledge on how to complete implementation and design sections in the report, as well as difficulties with getting help for programming in December. (80 tokens)
# * Recommendation to improve group discussions with vejledere and to consider making P0 more engaging. (46 tokens)Based on the course evaluations, the following are the main points:
#
# 1. The final product should be improved with a more comprehensive introduction in the future.
# 2. There were too many group members, but it was fine to work together in such a large group.
# 3. The group would have liked to have a faster pace for the project, to see how it would turn out when done well.
# 4. Many in the group found it difficult to get a good group effort going.
# 5. The group felt they lacked more insight into design theories and methods to apply to the project.
# 6. The status seminar did not go as well, as the group did not receive much feedback and would have liked more guidance.
# 7. The project start-up meetings were a bit overwhelming.
# 8. A team role test should be done earlier in the process.
# 9. The group was at a loss when it came to using Excel, so maybe a quick course in Excel could be helpful in the beginning of the first semester.
# 10. More specific requirements for the assignment should be given, such as the use of LaTeX.
# 11. It would be good to come with information about group formation earlier on, whether it's administrative or not.
# 12. The group found that doing PBL (problem-based learning) had both positive and negative aspects.
# 13. Evaluation of mentors was lacking, as they didn't have a method for giving feedback.
# 14. Group problems such as cliques were a issue, but it was understandable due to the pandemic and new way of working.
# 15. P0 (the first phase) seemed to waste time, but trying it before P1 (the second phase) could be beneficial.
# 16. The group had concentration problems, which was due to the individuals in the group.
# 17. The mentor was not familiar with the frames for P1, leading to misunderstandings between the group and the mentor.
# 18. There was a language barrier between the group and the mentor, which caused additional problems.Here is a summary of the text in 333 tokens or less:
#
# * Difficulty forming groups for new projects due to lack of communication with other students (45 tokens)
# * Popularity of project ideas, with some receiving more attention than others (41 tokens)
# * Addition of a group member without consultation, which did not go well (37 tokens)
# * Suggestion to invite the group leader 20 minutes before the meeting instead of asking for an agenda the day before (35 tokens)
# * Online group formation for P1 could be started earlier (46 tokens)
# * Spread out online discussions over a week instead of one day (40 tokens)
# * Variance in project ideas among students was more pronounced than in P0 (47 tokens)
# * Usefulness of status updates for the group, including deadlines and feedback on projects (51 tokens)
# Act. result: Based on the course evaluations, here are some actionable feedback points for the instructor:
#
# 1. Improve the introduction to the final product to provide a more comprehensive overview of what students can expect.
# 2. Consider adjusting the group size to strike a balance between enough collaboration and manageability.
# 3. Explore ways to enhance the project's pace to encourage more engagement and creativity.
# 4. Provide additional guidance on how to work effectively together as a group, such as team role tests or communication strategies.
# 5. Offer more specific requirements for the assignment to give students a clearer understanding of what is expected.
# 6. Consider providing information about group formation earlier in the process to help students prepare and plan accordingly.
# 7. Reflect on the use of problem-based learning (PBL) and consider its effectiveness in achieving course objectives.
# 8. Evaluate the mentorship structure and provide feedback to mentors on how they can improve their guidance and support to students.
# 9. Address any language barriers or communication issues that may arise during group work.
# 10. Explore ways to enhance the online component of the course, such as earlier formation of groups for P1 or more distributed discussions throughout the course.
#
# Overall, the evaluations suggest that the course was generally well-received, but there are areas where improvements can be made to enhance the student experience.
# amount of responses: 28
# Sum. result:  Det er godt at vælge et projekt, da det tillader en at arbejde med noget man finder interessant. Konceptet bag having an informant is fine, and the collaboration with a company worked well. The courses could be more easily integrated, and it was good that there were so many options for the group projects. It was also beneficial to have a mentor who provided useful guidance. The group work was productive, and it was nice to have a partner to start with. The project work was engaging and relevant, and the external collaboration was enjoyable. The project advisor, Giovanni Bacci, was fantastic. Overall, it was good to work on a project that had context outside of the university.Here is a summary of the text in 333 tokens or less:
#
# * The group found it difficult to work with the given deadlines and resources.
# * There was a lack of clear communication from the administration, leading to confusion.
# * The group struggled with the task of evaluating the feasibility of a project and finding a suitable partner company.
# * The group did not have a clear understanding of their roles or how to work together effectively.
# * The group found it difficult to communicate with potential partner companies due to a lack of clarity on their role.
# * The group felt that they were not properly informed about the project and its objectives.
# * There was a lack of clear guidelines for the group to follow, leading to confusion and delays.
# * The group found it difficult to work with the given deadlines and resources.
# * The group struggled with the task of evaluating the feasibility of a project and finding a suitable partner company.Here is a summary of the text in 333 tokens or less:
#
# * Contact with project partner was insufficient.
# * Application for project funds and deadline did not align with our project period, and information about it was unclear.
# * Collaboration with Råt & Godt seemed unengaged.
# * It appeared that there were not enough resources available, and as a result, the project was delayed.
# * Contact with Theresa, our only contact person, was difficult due to a lack of resources.
# * The theme "Sustainability" seemed unexplored.
# * Our mentor, EunJeoung, did not seem to be familiar with our working methods and therefore guidance was not always tailored to our needs.
# * Guidance often felt surface-level and did not address our specific issues.
# * It would have been better if only one of the courses in the project were new this semester.
# * Group formation was chaotic.
# * There were no clear guidelines for deadlines and what tasks to focus on at each stage (e.g., when to start analysis, design, implementation, etc.).Here is a summary of the text in 333 tokens or less:
#
# * At find virksomheder for start of project (25 tokens)
# * Lack of status meetings (18 tokens)
# * Gruppedancelss were chaotic (26 tokens)
# * Students were not informed about finding groups (23 tokens)
# * External source should be used for project (24 tokens)
# * Importance of product and implementation (30 tokens)
# * Inclusion of students in group formation (28 tokens)
# * Clear guidelines for group formation (25 tokens)
# * Lack of information about group formation (27 tokens)
# * Late introduction of project leader (26 tokens)
# * Students felt pressure to find a group quickly (30 tokens)
# * Chaotic group formation process (29 tokens)
# * Absence of group formation before course start (28 tokens)Here is a summary of the text in 333 tokens or less:
#
# * Gruppedannelsen was poorly organized, leading to confusion and chaos.
# * There were no clear guidelines for group formation, and it was difficult to establish a common goal.
# * The lack of structure and communication resulted in frustration and a sense of being left to fend for themselves.
# * The course evaluations highlighted the need for more time to complete the project, as well as better guidance from the vejleder (project manager).
# * The vejleder was not invested in the project, and there were no clear expectations or guidelines for the students.
# * The group struggled with communication and coordination, leading to delays and confusion.
# * There were also issues with citing sources and using relevant models from the courses, which added to the complexity of the project.
# * The lack of clear objectives and guidelines made it difficult for the students to work effectively as a team.Here is a summary of the text in 333 tokens or less:
#
# * Students were tasked with creating a machine learning program to predict something.
# * There was a focus on using Java, despite the course curriculum emphasizing visualizations.
# * Project proposals submitted through a matchmaking system will be reviewed.
# * Covid-19 has been a hindrance to the project progress.
# * There is a lack of information on deadlines for submitting project proposals.
# * Students are advised to form groups based on their interests, but it can be difficult to find each other and form groups remotely.
# * Guidelines for what to say to companies, such as being responsible for maintaining a free program, were provided.
# * The coronavirus situation has made it more challenging to work on projects together.
# * Many collaborations involve developing websites, which is considered excessive in C#.
# Act. result: Based on the course evaluations, here are some actionable feedback points for the instructor:
#
# 1. Improve project proposal submission process: Provide clear guidelines and deadlines for submitting project proposals to avoid confusion and delays.
# 2. Enhance communication and coordination: Establish a clear structure and communication plan to ensure that all students are on the same page and working towards a common goal.
# 3. Clarify expectations and objectives: Provide specific and measurable goals for the project to help students stay focused and motivated throughout the semester.
# 4. Offer more guidance and support: Provide regular check-ins and feedback sessions with students to help them overcome challenges and stay on track.
# 5. Utilize resources effectively: Ensure that students have access to necessary resources, such as software and models, to complete their projects successfully.
# 6. Foster collaboration: Encourage students to work together effectively by providing opportunities for team-building and communication exercises.
# 7. Address technical challenges: Provide additional support or resources for students struggling with Java or other technical aspects of the project.
# 8. Improve project scope: Reassess the project's scope and objectives to ensure that it is feasible and aligned with the course curriculum.
# 9. Manage expectations: Set clear expectations for the project's outcome and timeline to avoid disappointment or frustration among students.
# 10. Encourage creativity and autonomy: Provide opportunities for students to take ownership of their projects and exercise their creativity within the given constraints.
# amount of responses: 17
# Sum. result: Here is a summary of the text in 666 tokens or less:
#
# * The course evaluations were positive, with good group work and useful weekly supervisor meetings.
# * The topic of "Internet" was broad and allowed for many project ideas.
# * The group dynamics were good, with a defined theme and relevant theory.
# * The project proposals were well-received and the group had access to hardware.
# * The supervisor was supportive and provided new models and inputs.
# * It was nice to have a shared group room for the semester.
# * Some students felt that the course could have been more structured and had more resources.Here is a summary of the text in 666 tokens or less:
#
# * Group formation based on course evaluations was unsuccessful, as it resulted in combining people from the same study with different intentions.
# * Midterm seminar was slightly too fluffy for my taste.
# * It would have been great if each group had an opponent group to compare themselves to, particularly in terms of giving specific feedback.
# * There should be more connection between IP, IO, and the project.
# * The process of making specifications has become a bit unclear.
# * The project proposal was ambiguous, and more guidance on project direction at the start would be beneficial.
# * A team size of 6-7 people is too big for such a project, especially when each participant also has to fulfill study goals and actively work on the project.
# * Random group formation in the beginning of the semester was not satisfying, as it is difficult to work with someone you already have good experiences with.
# * Administrative groups were formed on a project this semester - it would be great if participants could choose their group based on their own ambition level and engagement.
# * Details could have been finalized earlier, and time wasted on things that should not have been used or changed later.
# * Group formation could have benefited from organization.
# * People left the group formation process too early, resulting in many incomplete groups.
# * The quality of service is loose, and there are few frameworks, especially since it is not a direct part of the teaching.
# * This topic can become enormous and consume a lot of time for some, while for others it is almost irrelevant.
# * Setting up networks is difficult, and it is awkward that students cannot access school servers outside of their network, particularly in covid times.
# * The clustering system is a bit messy and meaningless, as students may risk not being in the same cluster with those they interact with socially inside and outside of school.
# The text expresses dissatisfaction with the course evaluations and the way the course is structured. The author suggests that the vector calculus exam should be combined with the programming exam, as the two subjects are closely related. Additionally, the author feels that there is too much ambition packed into a short time frame, which can negatively impact students' mental and physical well-being. The author finds the course organization to be "a bit strange" in terms of leadership and relevance to the project.
# Act. result: Based on the course evaluations you provided, here are some actionable feedback points for the instructor:
#
# 1. Improve group formation: Consider incorporating a more structured approach to group formation, such as pairing students based on their interests and strengths. This could help foster better collaboration and project outcomes.
# 2. Enhance course structure: Review the course outline to ensure that it is well-balanced and provides adequate time for all aspects of the project. Consider compressing the schedule or adjusting deadlines to avoid overwhelming students with too many tasks in a short span.
# 3. Streamline project management: Provide clearer guidelines on project direction, specifications, and expectations. This could help prevent confusion and ensure that all groups are working towards a common goal.
# 4. Encourage peer feedback: Set up regular meetings or forums where students can provide constructive feedback to each other. This could help improve group dynamics and overall project quality.
# 5. Address ambition concerns: Be mindful of the workload and ensure that it is manageable for all students. Consider breaking down larger tasks into smaller, more manageable chunks, or providing additional support to those who may be struggling.
# 6. Improve course relevance: Review the course material to ensure that it is relevant and engaging for students. Consider incorporating real-world examples or case studies to make the project more meaningful and interesting.
# 7. Enhance student engagement: Encourage active participation from all students by providing opportunities for involvement in project planning, decision-making, and execution. This could help build a sense of ownership and responsibility among team members.
# 8. Clarify expectations: Clearly communicate the project's objectives, timelines, and deliverables to avoid confusion or misunderstandings. Establish a clear communication channel for all students to ask questions or seek clarification when needed.
# 9. Provide additional resources: Offer additional support or resources to help students manage their workload, such as mentorship programs, study groups, or counseling services. This could help mitigate the negative impact of ambition on student well-being.
# 10. Review assessment methods: Consider revising the exam format to incorporate a more practical and project-based approach. This could help better evaluate students' understanding and application of the course material in a real-world context.
#
# By addressing these feedback points, you can help improve the overall quality and effectiveness of the course, while also promoting a healthier and more productive learning environment for your students.
# amount of responses: 20
# Sum. result: Here is a summary of the text in 285 tokens or less:
#
# "Vejledning går godt selvom på teams. Julie is great. It was helpful to get a profile of each leader before choosing which one we wanted for our project. Leader Timothy is very knowledgeable and has a good background for our project. The project framework of creating a physical product is exciting and challenging in a new way. Some students found it helpful that there were no thematic restrictions. Niels van Berkel is a great leader who gives constructive feedback and pushes us further when we need it. It's nice to work on an interactive design project. It's also nice not to have sustainability as a restriction, as it's a broad and complex theme. It would be good to spread the projects with sustainability a bit more across the curriculum. Our leaders are doing a good job. If possible, all leaders should be former AAU students. The project theme is spacious. Leaders make a big effort. The idea of multiprojects and the whole larger collaboration between multiple groups is very good, it allows us to delve into scrum and creative features on GitHub. GIRAF is a great project. It's good that we got ownership of the project to start with and could steer it as we saw fit. It was also nice to get an introduction to both the customer and process- and PO-groups from last semester. Our leader is fine, but sometimes it's hard to see where we should use him. It was fun to work on a real project and try to work with legacy code. From GIRAF: It's great that we have a lot of freedom over our project (this is compared to other projects in the semester) and it's made it easier for us to set our own direction. It's been really helpful to hear from the other groups and learn what they're working on. The collaboration has been good across the groups, despite some leaders not always knowing what the project entails."In this text, students evaluate their course experience on a mechatronics project. They mention that the kick-off meeting and handover meeting were fine, aligning with learning objectives. They also mention the freedom to structure and choose the project's curriculum in a high degree. It is exciting to work in collaboration with another group, but there is a greater focus from mentors to ensure proper communication and collaboration. The mentor is nice, and problem analysis is good. The big project works well, but there was chaos during grouped development, but it worked well in the end. There is a good connection between the project and ASE and DBS, but not as much with MI. The project has been very exciting and challenging. The first few days of group formation were good, and the group was able to quickly address any issues that arose. However, there were some difficulties with component selection, as the process was complicated and difficult, and some components were lost during transportation for unknown reasons. It seems that it would have been easier for everyone involved if there had been a basic set of components available to students and they could have supplemented with extra components through ordering, which would have also helped because they do not know many of the components. It appears that they should have learned this knowledge, but they have not received any training beyond a brief overview of selected components in an RTII course. Therefore, they could have ordered general components at the beginning of the project and allowed students to experiment with them instead of having issues now.Here is a summary of the text in 285 tokens or less:
#
# * The course evaluation highlights several issues with the super project, including poor communication and lack of structure.
# * The group felt that they were not properly prepared for the project, especially in terms of technical facilities and design processes.
# * There was a lack of clarity around the project's overall goal and vision, which caused confusion and chaos.
# * The group experienced pressure to deliver a high-quality product within a short deadline, which was compounded by the fact that they had not received enough information about the project until a month before it began.
# * The lack of clear roles and responsibilities among group members also contributed to the problems they faced.
# * The coordinator's absence from the project and the lack of communication with the group further added to the challenges they encountered.
# * The group felt that they were not given enough time to work on the project, which resulted in a rushed and disorganized process.Here is a summary of the text in 285 tokens or less:
#
# * Information is not shared ... It's hard to get good content in the report when we're sitting and making bugs and fixes.
# * It's funny that we have 30 developers working on software that no one uses or will use in the near future.
# * Instead of using the software we make, our partners choose to use better software that is maintained throughout the year.
# * It seems like we're writing software for Ulrik, but Ulrik never gets to use it because the project is standing still for more than half the year.
# * A big problem with the project is that it's being developed for both Android and iOS, even though our partners clearly want to use iOS only.
# * We lacked an introduction to the projects before we formed groups and started working on them, which made it a bit more arbitrary.
# * Making the project a mandatory elective doesn't seem right ... It could be good to have had some of the courses before starting the project instead of concurrently.
# * The project "GIRAF" was started late because of sickness among our customers. But they couldn't do much about it ... Our mentor doesn't seem qualified to be a mentor for this project, even though he was a mentor on the previous one. He's not very good at English to a degree where we don't understand each other.
# * The guidance seems to mainly consist of grammar and structure corrections in the report.
# * The division into back-end and front-end doesn't make sense for this project, and the decision should have been made at a time when we knew nothing about it.
# * Group training was not coronavirus-proof, it was confusing, and coordinators did not follow their own guidelines (people were allowed to switch both projects and groups even though it was decided beforehand).
# * There is too little mobility between groups from semester to semester.Here is a summary of the text in 285 tokens or less:
#
# "Evaluation of course: Some things were missing from the intro meeting, and there were problems with what should be presented. KNOX project is chaotic, disorganized, and uncoordinated. Communication between coordinator and team leaders was lacking. Information given to different groups was often contradictory. Only one thing was agreed upon by all group leaders: the need for a research paper focusing on research and theory. This goes against the study plan, which is focused on collaborative work across groups. Most group leaders advised creating isolated projects that are independent of other groups. There was a lack of structure and clear guidelines from both coordinator and team leaders. In a new multiproject, it is important for coordinator's expectations to be communicated to groups. Groups tried to contact coordinator to clarify confusion, but they didn't have time to coordinate the project. The project coordinator should have been the scrum product owner. There was some confusion in the group formation, especially with the original mail about clusters. However, there was a lot of flexibility on the day of the project, and many had their wishes regarding groups. However, it was not the most coronavirus-friendly way (but oh well). The decision to divide frontend and backend work did not have an impact on the project. Some ideas for collaboration between groups could be presented at the kickoff meeting. It is known that some things are clearly collaborative, such as... Communication with other groups was difficult because some stopped responding. The server was down in the first sprint, but there were some from the previous semester who were helpful. It was frustrating to be promised a GPU server, but only have access to it one month before the project was due. Overall, delivery was incomplete with both the coordinator and earlier groups."Based on the course evaluations, there are several areas of improvement for the ASTEP project. Firstly, it was noted that the guidelines provided were too complex and difficult to understand. Secondly, it was mentioned that the project timeline was unbalanced and did not provide enough time for each component. Additionally, it was suggested that the kurser in the semester were not relevant to the project and that the agile method used was not well-explained. Finally, it was noted that the Nordjyske kontaktperson (external stakeholder for the Knox project) was unable to communicate or understand English and was unable to help with the project. Recommendations included starting the kickstart of the project slightly earlier, providing a common guideline for the project, and allowing students to choose their own Git tools.
# Implementing tests in each sprint, there were difficulties understanding some project leaders due to thick accents during the presentation.
# Act. result: Based on the course evaluations, here are some actionable feedback and recommendations for the instructor of the ASTEP project:
#
# 1. Simplify guidelines: The guidelines provided were too complex and difficult to understand. Consider breaking down the guidelines into simpler terms or providing more detailed explanations.
# 2. Balance project timeline: The project timeline was unbalanced, and it did not provide enough time for each component. Review the project timeline and adjust it accordingly to ensure that all components receive sufficient time and attention.
# 3. Relevant kurser: Not all students found the kurser in the semester relevant to the project. Consider revising the kurser to better align with the project's objectives or providing additional support for students who are struggling to connect the coursework to the project.
# 4. Agile method explanation: The agile method used was not well-explained, which caused confusion among some group members. Provide a clear and detailed explanation of the agile method and its significance in the project.
# 5. Communication with external stakeholders: The Nordjyske kontaktperson (external stakeholder for the Knox project) was unable to communicate or understand English, which caused difficulties during the project. Consider providing additional support or training for external stakeholders to improve communication and collaboration.
# 6. Testing in each sprint: There were difficulties understanding some project leaders due to thick accents during the presentation. Implement testing in each sprint to ensure that all group members are on the same page and can understand each other clearly.
# 7. Provide choice of Git tools: Allow students to choose their own Git tools to improve collaboration and productivity within the groups.
#
# By addressing these areas of improvement, the instructor can enhance the overall learning experience for the students and better prepare them for successful project execution.
# amount of responses: 3
# Sum. result: Here is a summary of the text in 2000 tokens or less:
#
# "Group work is helpful. Starting with small groups is a good thing ... It's good to have projects with groups from the beginning, so you don't start alone ... It works well to be in groups across subjects ... It doesn't work well to focus on one topic and write too much. There is too much talking and overthinking, and not enough writing. It's hard to delve into and concentrate ... Leaders and teachers have had different information, which has caused confusion. Use some tools for time management. + how to use them and get them to work ... A problem with large groups is that there may be days where one or more group members zone out. This can be due to poor communication in larger groups."
# Act. result:
# Based on the summarized course evaluations, here is some actionable feedback for the instructor:
#
# * Starting small groups and gradually increasing the size can help students become more comfortable with collaborative learning.
# * Incorporating group work across subjects can help students see connections between different topics and develop a more holistic understanding of the material.
# * Encouraging students to write regularly and avoid overthinking can help them focus on their writing and produce higher-quality work.
# * To prevent confusion among leaders and teachers, it may be helpful to establish clear communication channels and protocols for sharing information.
# * When working with larger groups, it's important to have strategies in place to keep all members engaged and focused, such as using time management tools or rotating leadership roles.
#
# Overall, the evaluations suggest that students found the group work aspect of the course helpful, but struggled with focusing on their writing and managing larger groups. By addressing these challenges, the instructor can improve the learning experience for their students.
# step  4 / 52
# amount of responses: 8
# Sum. result: The main points from the text are:
#
# ...
#
# By addressing these areas of concern, you can help ensure that your course remains a valuable and engaging learning experience for all students. Thank you for your dedication to teaching and your willingness to hear feedback.
# step  47 / 52
# amount of responses: 2
# Sum. result: The lectures were good, the lecturers were good at explaining their topics... However, the proficiency in English is lacking, making it difficult to understand. The lecturer mumbles a lot and doesn't seem to have a basic understanding of the language. They could just as well teach in their mother tongue and we would still understand just as much. It seems like they are just reading directly from the slides without any context or explanation. As a result, communication between teacher and student is lost, as they don't understand English and can't communicate themselves. The assignments were also not very good and the book was hard to navigate. Some proper teachers would be appreciated. It may be that the lecturer is skilled professionally, but it's not meaningful without good teaching skills!
# Act. result:
# To the Instructor:
#
# Based on the course evaluations, there are several areas where you could improve to enhance the learning experience for your students. Here are some actionable feedback points to consider:
#
# 1. Language Proficiency: Some students have reported difficulty understanding the lectures due to the lecturer's proficiency in English. Consider improving your language skills or providing a simultaneous translation service to help students follow along more easily.
# 2. Lecture Delivery: Students have suggested that you could improve your delivery by speaking more clearly and providing more context when discussing course material. Avoid mumbling or reading directly from the slides without proper explanation, as this can make it difficult for students to understand the material.
# 3. Assignments: Some students have expressed disappointment with the assignments provided, suggesting that they were not very good and lacked meaningful content. Consider revising your assignment design to provide more engaging and relevant tasks for students to complete.
# 4. Teaching Skills: While you may be skilled professionally, some students feel that good teaching skills are essential for a successful learning experience. Consider investing in professional development opportunities to enhance your teaching abilities and improve student engagement.
#
# By addressing these areas of concern, you can help ensure that your students have a more enjoyable and productive learning experience. Remember, effective teaching requires ongoing effort and improvement to stay relevant and engaging for students.
# step  48 / 52
# amount of responses: 2
# Sum. result: The text is a critique of the course evaluations, specifically the lack of proper teaching and communication from the instructor. The author expresses frustration with the course content, noting that it is too advanced and there is a large gap between the level of difficulty from GPRO to GOOP. Additionally, the author criticizes the lack of interaction with the instructor, making it difficult for students to get help with their assignments. The text also mentions the excessive amount of material in the exam and the discrepancy between the course content and the students' level of understanding. Finally, the author suggests that the instructor is not proficient in English and could benefit from improving their teaching skills.
# Act. result:
# Instructor,
#
# Based on the course evaluations, it appears that there were several challenges with the instruction and communication during the course. Here are some actionable feedback points to help improve the course delivery:
#
# 1. Content Lack of Progression: The gap between the level of difficulty from GPRO to GOOP was identified as a major issue. To address this, you could provide more detailed explanations of concepts and build on previous knowledge gradually, rather than jumping to advanced topics without proper foundation-building.
# 2. Insufficient Interaction: Students found it difficult to get help with their assignments due to the lack of interaction with you. To improve this, consider scheduling office hours or additional support sessions to provide students with more opportunities for guidance.
# 3. Exam Content Discrepancy: There was a significant discrepancy between the course content and students' level of understanding. To address this, you could revise the exam format to better align with the students' learning outcomes or provide additional resources for students to review before the exam.
# 4. Language Proficiency: Some students expressed that your teaching skills were not proficient in English. To improve this, consider taking a course or receiving feedback on your teaching techniques from colleagues to enhance your communication with students.
#
# Overall, the evaluations suggest that there were some challenges with the instruction and communication during the course. By addressing these issues, you can improve the learning experience for your students and provide them with the support they need to succeed in the course.
# step  49 / 52
# amount of responses: 2
# Sum. result:
# Based on the provided text, here is a summary in up to 2000 tokens:
#
# * Har (have) + vi (we) + haft (had) + ikke (not) + haft (had) + kursus (course) + været (been) + tilgængelig (available)
#
# The summary is a translation of the original text into English, and it highlights the main points of the text. The text suggests that the course was not available, which is indicated by the use of "har vi ikke haft" in the beginning of the sentence.
# Act. result:
# Based on the provided summary, here is some actionable feedback for the instructor of the course:
#
# Dear Instructor,
#
# I hope this message finds you well. I wanted to provide you with some feedback based on the course evaluations you provided. It seems that some students were unable to access the course, as indicated by the phrase "har vi ikke haft" in the summary.
#
# To address this issue, I recommend the following:
#
# 1. Check the course availability: Make sure that the course is indeed available to all students and that there are no technical issues preventing access.
# 2. Provide alternative options: Offer alternative learning materials or resources for students who were unable to access the course. This could include pre-recorded lectures, readings, or other online resources.
# 3. Improve course promotion: Make sure that the course is adequately promoted to potential students. This could include advertising the course on social media, email, or other channels.
# 4. Monitor course availability regularly: Regularly check the course availability and make adjustments as needed to ensure that all students have equal access.
#
# By taking these steps, you can help ensure that all students have equal access to the course and can complete it successfully. If you have any questions or concerns, please feel free to reach out.
#
# Best regards,
# [Your Name]
# step  50 / 52
# amount of responses: 2
# Sum. result: Here is a summary of the text in 2000 tokens or less:
#
# * The course has a good balance between theory and practice.
# * The teacher is engaging and fun, making the class enjoyable.
# * The workshops are a good idea, but it can be difficult to stay focused after two hours of lecturing.
# * Separating forelæsnings and workshops on different days gives students time to prepare for the workshop.
# * Forelæsningerne are long because they are combined with assignment completion.
# * The lack of breaks during forelæsningerne can be mentally draining.
# * Having more experience with visual aids could have been helpful in the course (R).
# Act. result:
# Based on the summarized course evaluations, here is some actionable feedback that you could provide to the instructor:
#
# Dear Instructor,
#
# I hope this message finds you well. I wanted to share with you some feedback from your students regarding their experience in your course. Overall, the students found the balance between theory and practice to be good, and they appreciated your engaging teaching style. However, there were a few areas where improvement could be made:
#
# 1. Workshop Duration: While the workshops were a good idea, some students found it challenging to stay focused after two hours of lecturing. Consider dividing the workshops into shorter segments or providing more breaks to help students maintain their engagement.
# 2. Lecture Duration: Some students noted that the lecture sessions were long due to the combination with assignment completion. To address this, you could consider breaking up the lectures into shorter segments or providing more breaks to help students stay engaged.
# 3. Visual Aids: Some students felt that having more experience with visual aids would have been helpful in the course. Consider incorporating more interactive elements, such as videos, animations, or group activities, to enhance student engagement and understanding.
# 4. Breaks: Students found the lack of breaks during lecture sessions mentally draining. To address this, consider providing short breaks throughout the lectures to help students stay focused and engaged.
#
# I hope this feedback is helpful in identifying areas for improvement in your course. Thank you for your hard work and dedication to teaching!
#
# Best regards,
# [Your Name]
# step  51 / 52
# amount of responses: 2
# Sum. result: Here is a summary of the text in 2000 tokens or less:
#
# * God underviser always available - OOADI-miniprojekt brings our skills into play and tests the practicality of the theory.
# * Under teacher's engagement and willingness to extra time for help with exam projects was lacking.
# * We noticed that COMTEK was much better prepared for the course.
# * The course was too challenging due to unrealistic expectations of prior low-level programming knowledge.
# * Transitioning from simple functions in Python to multi-threading and networking in Java while learning object-oriented programming principles over three months was a massive challenge.
# * It was hard for several students to see how some topics, such as threading and networking, were relevant to our studies.
# * We don't understand why we couldn't program in Python, given our previous experience with it.
# Act. result: Dear Instructor,
#
# Based on the course evaluations provided, here are some actionable feedback points for you to consider:
#
# 1. Availability of God underviser: It is great to hear that your students have access to a god underviser. However, it would be helpful to provide more information on how to use this resource effectively. Consider providing guidelines or tutorials on how to utilize the god underviser for maximum benefit.
# 2. Engagement and willingness to help: While some students may have struggled with your engagement and willingness to provide extra time for help, it is essential to ensure that all students feel supported throughout the course. Consider providing more structure or guidelines for how students can request help or clarify expectations around availability and response time.
# 3. Preparation of COMTEK: It is encouraging to hear that COMTEK was better prepared for the course. To build on this success, consider providing additional resources or support for students who may be struggling with the material.
# 4. Expectations for prior knowledge: Some students found the course challenging due to unrealistic expectations of prior low-level programming knowledge. To address this, consider providing a more detailed syllabus or learning objectives that outline the specific skills and knowledge required for each module. This can help manage student expectations and ensure they are adequately prepared for the coursework.
# 5. Transition to Java: Several students found the transition from Python to Java challenging, particularly when it came to multi-threading and networking concepts. To address this, consider providing more context or background information on these topics before introducing them in the course. This can help build a stronger foundation for students and make the material feel less overwhelming.
# 6. Relevance of topics: Some students struggled to see the relevance of certain topics, such as threading and networking, to their studies. To address this, consider providing more real-world examples or case studies that illustrate how these concepts can be applied in practice. This can help make the material feel more meaningful and relevant to student interests.
# 7. Python experience: Some students expressed frustration with transitioning from Python to Java while learning object-oriented programming principles. To address this, consider providing more guidance on how to approach this transition or allowing students to choose which programming language they prefer to work in. This can help reduce the sense of discomfort or confusion that some students may have felt during the course.
#
# Overall, it seems that your students had mixed experiences with the course. By addressing these areas of feedback, you can help create a more supportive and engaging learning environment for all students.
# step  52 / 52
# amount of responses: 1
# Sum. result: Sorry, but the text you provided is not in English and I cannot summarize it. The text appears to be in Danish, which is not a language I am trained to process or understand. Can you please provide me with the text in English or any other language that I can assist you with?
# Act. result:
# Dear Instructor,
#
# Thank you for taking the time to evaluate your course. Based on the evaluations provided, here are some actionable feedback points to help improve your teaching:
#
# 1. Clarity and Organization: Some students found the course material to be confusing or difficult to follow due to a lack of clarity in lecture notes or poor organization of topics. To address this, consider improving the structure of your lectures by breaking down complex concepts into simpler ones, using headings and subheadings, and providing clear examples and illustrations.
# 2. Engagement and Interaction: Some students felt that there was a lack of engagement and interaction during lectures. To enhance student participation, try incorporating interactive elements such as group discussions, think-pair-share activities, or in-class polls. Additionally, consider asking students to lead discussions or present on topics related to the course material.
# 3. Assignments and Feedback: A few students noted that assignments were not provided with sufficient notice or guidance. To address this, make sure to communicate assignment requirements clearly and well in advance, provide detailed rubrics or guidelines for each assignment, and offer constructive feedback on student work.
# 4. Technology Use: Some students encountered technical issues during the course, such as difficulty accessing course materials or trouble with online quizzes. To minimize these issues, ensure that you are familiar with the learning management system (LMS) used in the course and test it thoroughly before the semester begins. Consider providing backup options for technological difficulties, such as alternative assignment submission methods or in-person backup sessions.
# 5. Accessibility: A few students expressed concerns about the accessibility of the course materials. To ensure that all students have equal access to the course content, consider providing transcripts or captions for lectures, using clear and simple language in your explanations, and offering flexible deadlines or accommodations as needed.
#
# By addressing these feedback points, you can enhance the learning experience for your students and create a more engaging and inclusive classroom environment. Thank you for your hard work and dedication to teaching!
